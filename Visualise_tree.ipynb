# %%
import graphviz

# %%
with open("./Tree_visual/dtbot.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
with open("./Tree_visual/dtmid.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
with open("./Tree_visual/dttop.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
